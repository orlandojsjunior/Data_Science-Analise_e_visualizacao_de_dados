# %% [markdown]
# <a href="https://colab.research.google.com/github/orlandojsjunior/Data_Science/blob/main/Dados-e-visualizacoes/Notebooks/aula_0_Introdu%C3%A7%C3%A3o_a_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

URL = "https://raw.githubusercontent.com/orlandojsjunior/Data_Science/main/Dados-e-visualizacoes/Dados/ratings.csv"

notas = pd.read_csv(URL)
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuarioId", "filmeId", "notas", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  notas    momento
# 0          1        1    4.0  964982703
# 1          1        3    4.0  964981247
# 2          1        6    4.0  964982224
# 3          1       47    5.0  964983815
# 4          1       50    5.0  964982931

# %%
notas['notas'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['notas'].value_counts()
# Out:
# notas
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas['notas'].mean()
# Out:
# 3.501556983616962
